# %%
# %pylab inline
import pandas as pd
from sklearn.cluster import KMeans
rcParams['figure.figsize'] = 10, 5 #in inches
matplotlib.rcParams.update({'font.size': 14})
import seaborn as sns
from IPython.display import FileLink, FileLinks, Image
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['dist', 'colors', 'var']
# `%pylab --no-import-all` prevents importing * from pylab and numpy

# %% [markdown]
# # Testing clustering

# %%
data = pd.DataFrame.from_csv('data/data_summary', index_col=0)

# %%
X = data[['Gini','GDP_sum_norm_100']]

# %% [markdown]
# 5 cluster, to describe the world. Tentative check with elbow method.

# %%
k_means = KMeans(n_clusters=5,random_state=10)  
k_means.fit(X);
y_pred = k_means.predict(X)

color_map =  cm.rainbow_r
fig,ax = subplots()
scatt = ax.scatter(X.Gini, X.GDP_sum_norm_100, c=y_pred, cmap = color_map)
a = fig.colorbar(scatt,ticks=[0,1,2,3,4],label='group')

y_predrange = max(y_pred) - min(y_pred);
y_pred_n= (y_pred - min(y_pred)) / float(y_predrange);


for label, x, y ,yp  in zip(data.index, data.Gini, data.GDP_sum_norm_100, y_pred_n):
    c= matplotlib.colors.rgb2hex(color_map(yp))
    ax.annotate(
        label[:3], 
        xy = (x, y), xytext = (1,
                               1),fontsize=11, weight= 'semibold',color='white', horizontalalignment='center',
        bbox = dict(color = c , alpha = .9),
        textcoords = 'offset points')
ax.set_ylabel('g (USD\years)')
ax.set_xlabel(r'<Gini index>$_{year: %.i - %.i }$ '%(1990,2010));

# %% [markdown]
# ## Testing elbow method

# %%
from scipy.cluster.vq import kmeans,vq
from scipy.spatial.distance import cdist

##### cluster data into K=1..10 clusters #####
#K, KM, centroids,D_k,cIdx,dist,avgWithinSS = kmeans.run_kmeans(X,10)
XX = array([X.Gini, X.GDP_sum_norm_100])
K = range(1,20)

  # scipy.cluster.vq.kmeans
KM = [kmeans(X.values,k) for k in K] # apply kmeans 1 to 10
centroids = [cent for (cent,var) in KM]   # cluster centroids

D_k = [cdist(X.values, cent, 'euclidean') for cent in centroids]

cIdx = [np.argmin(D,axis=1) for D in D_k]
dist = [np.min(D,axis=1) for D in D_k]
avgWithinSS = [sum(d)/X.shape[0] for d in dist]

# %%
kIdx = 4 # 5 clusters
# plot elbow curve
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(K, avgWithinSS, 'o-')
ax.plot(K[kIdx], avgWithinSS[kIdx], marker='o', markersize=12, 
      markeredgewidth=2, markeredgecolor='r', markerfacecolor='None')
plt.grid(True)
plt.xlabel('Number of clusters')
plt.ylabel('Average within-cluster sum of squares')
tt = plt.title('Elbow for K-Means clustering')

# %%
data['counts'] = y_pred

# %%
data.index[y_pred==0]
# Out:
# Index([u'Afghanistan', u'Albania', u'Algeria', u'Armenia', u'Azerbaijan', u'Bangladesh', u'Belarus', u'Benin', u'Bhutan', u'Bosnia and Herzegovina', u'Bulgaria', u'Burundi', u'Cambodia', u'Cameroon', u'Chad', u'China', u'Cote d'Ivoire', u'Croatia', u'Czech Republic', u'Djibouti', u'Egypt, Arab Rep.', u'Estonia', u'Ethiopia', u'Gabon', u'Georgia', u'Ghana', u'Greece', u'Guinea', u'Guinea-Bissau', u'Hungary', u'India', u'Indonesia', u'Iran, Islamic Rep.', u'Iraq', u'Jordan', u'Kazakhstan', u'Korea, Rep.', u'Kyrgyz Republic', u'Lao PDR', u'Latvia', u'Liberia', u'Lithuania', u'Macedonia, FYR', u'Mali', u'Mauritania', u'Moldova', u'Mongolia', u'Montenegro', u'Morocco', u'Nepal', u'Niger', u'Pakistan', u'Poland', u'Portugal', u'Romania', u'Russian Federation', u'Serbia', u'Sierra Leone', u'Slovak Republic', u'Slovenia', u'Sri Lanka', u'St. Lucia', u'Sudan', u'Syrian Arab Republic', u'Tajikistan', u'Tanzania', u'Thailand', u'Togo', u'Trinidad and Tobago', u'Tunisia', u'Turkey', u'Turkmenistan', u'Uganda', u'Ukraine', u'Uzbekistan', u'Vietnam', u'West Bank and Gaza', u'Yemen, Rep.'], dtype='object')

# %%
data.index[y_pred==1]
# Out:
# Index([u'Australia', u'Austria', u'Belgium', u'Canada', u'Denmark', u'Finland', u'France', u'Germany', u'Hong Kong SAR, China', u'Ireland', u'Israel', u'Italy', u'Japan', u'Luxembourg', u'Netherlands', u'New Zealand', u'Norway', u'Qatar', u'Singapore', u'Spain', u'Sweden', u'Switzerland', u'United Kingdom', u'United States'], dtype='object')

# %%
data.index[y_pred==2]
# Out:
# Index([u'Angola', u'Argentina', u'Belize', u'Bolivia', u'Botswana', u'Brazil', u'Burkina Faso', u'Cape Verde', u'Central African Republic', u'Chile', u'Colombia', u'Comoros', u'Congo, Dem. Rep.', u'Congo, Rep.', u'Costa Rica', u'Dominican Republic', u'Ecuador', u'El Salvador', u'Fiji', u'Gambia, The', u'Guatemala', u'Guyana', u'Haiti', u'Honduras', u'Jamaica', u'Kenya', u'Lesotho', u'Madagascar', u'Malawi', u'Malaysia', u'Maldives', u'Mexico', u'Micronesia, Fed. Sts.', u'Mozambique', u'Namibia', u'Nicaragua', u'Nigeria', u'Panama', u'Papua New Guinea', u'Paraguay', u'Peru', u'Philippines', u'Rwanda', u'Sao Tome and Principe', u'Senegal', u'Seychelles', u'South Africa', u'South Sudan', u'Suriname', u'Swaziland', u'Uruguay', u'Venezuela, RB', u'Zambia', u'Zimbabwe'], dtype='object')

# %% [markdown]
# Set 4, spot on.

# %%
data.index[y_pred==4]
# Out:
# Index([], dtype='object')

# %% [markdown]
# Do simple linear correlation exist within each cluster ?

# %%
props = [0,1,2,3] #group 4 excluded, poor statistic and obvious. 
colors = ['slategray','seagreen','MediumPurple','dodgerblue']
for prop, color in zip(props,colors):
    df = pd.DataFrame(data.GDP_sum[y_pred==prop],index=data.index[y_pred==prop].values)
    df['Gini'] = data.Gini[y_pred==prop]
    ax = sns.regplot('Gini','GDP_sum',df, color=color )
    title('Group no:{0}'.format(prop), loc='left')

# %% [markdown]
# Notes: Group 3 and 2 are strangely tailed.

# %% [markdown]
# ## Qualitative geograhpical clustering

# %%
import vincent
import json

# %%
world_topo = r'world-countries.topo.json'

geo_data = [{'name': 'countries',
             'url': world_topo,
             'feature': 'world-countries'}]

vis = vincent.Map(geo_data=geo_data, scale=200)

# %%
with open(world_topo, 'r') as f:
    get_id = json.load(f)

# %%
names = []
for geom in get_id['objects']['world-countries']['geometries']:
    names.append(geom['properties']['name'])

# %%
countries = pd.Series(data= array(names),name='countries')
data_template = pd.DataFrame(countries)
data_template['val'] = linspace(0,10,num=len(countries.index))

# %%
data_map = {}
for j in data_template.countries:
    data_map[j] = 0 
    for i in data.index:
        if i in j:
            data_map[j] = data.counts[i]
        elif i in j.lower():
            data_map[j] = data.counts[i]
        elif j in i:
            data_map[j] = data.counts[i]
        elif j.lower() in i:
            data_map[j] = data.counts[i]

# %%
a = pd.DataFrame.from_dict(data_map, orient='index')
a['countries'] = a.index
a['counts'] = a[0]

# %%
vis = vincent.Map(data = a, geo_data=geo_data, data_bind='counts', data_key='countries', 
                  map_key={'countries':'properties.name'}, scale=200,brew='RdPu')

# visual fixes to the map 
vis.scales[0].type='quantile' # quantatitive 
unique_val = np.unique(a.counts.values)  # array of unique counts (i.e per country)
vis.scales['color'].domain = list(unique_val) # takes only list dtype

vis.legend("Cluster no: ")

# %%
vis.to_json('vis.json', html_out=True)

# %% [markdown]
# Embedded view for the web:
#
# ![test](https://raw.github.com/giulioungaretti/stats2013/master/Project2/Map.png)

# %% [markdown]
# Run locally

# %%
FileLink('vega_template.html')
# Out:
# /Users/Giulio/Documents/Uni/Master/stats/Project2/vega_template.html

# %%
#or uncomment the two lines and serve your own server! 
# !open http://127.0.0.1:8000/vega_template.html
# ! python -m SimpleHTTPServer

# %%
from IPython.core.display import HTML
def css_styling():
    styles = open("styles/custom.css", "r").read()
    return HTML(styles)
css_styling()
